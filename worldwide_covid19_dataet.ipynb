# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df_a=pd.read_csv("country_wide_covid19.csv")
df_a.head(40)
# Out:
#           Date       Country  Population  Total Tests  Total Cases  \
# 0   2020-04-18           USA   330774664    3722145.0     738792.0
# 1   2020-04-18        Russia   145927292    1831892.0      36793.0
# 2   2020-04-18         Spain    46752703     930230.0     194416.0
# 3   2020-04-18        Brazil   212380932      62985.0      36722.0
# 4   2020-04-18            UK    67844241     460437.0     114217.0
# 5   2020-04-18         Italy    60471924    1305833.0     175925.0
# 6   2020-04-18        France    65256826     463662.0     151793.0
# 7   2020-04-18       Germany    83752855    1728357.0     143724.0
# 8   2020-04-18        Turkey    84230075     598933.0      82329.0
# 9   2020-04-18          Iran    83862642     330137.0      80868.0
# 10  2020-04-18         India  1378381772     335123.0      16365.0
# 11  2020-04-18          Peru    32915899     135895.0      14420.0
# 12  2020-04-18         China  1439323776          NaN      82719.0
# ...

# %%
df_a.shape
# Out:
# (6603, 9)

# %%
df_a.nunique()
# Out:
# Date                     31
# Country                 213
# Population              213
# Total Tests            3173
# Total Cases            3257
# Total Deaths           1185
# Total Recovered        2268
# Serious or Critical     529
# Active Cases           2680
# dtype: int64

# %%
df_a.dtypes
# Out:
# Date                    object
# Country                 object
# Population               int64
# Total Tests            float64
# Total Cases            float64
# Total Deaths           float64
# Total Recovered        float64
# Serious or Critical    float64
# Active Cases           float64
# dtype: object

# %%
df_a["Date"]=pd.to_datetime(df_a["Date"])
# Out:
# dtype('<M8[ns]')

# %%
df_a.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Population                      int64
# Total Tests                   float64
# Total Cases                   float64
# Total Deaths                  float64
# Total Recovered               float64
# Serious or Critical           float64
# Active Cases                  float64
# dtype: object

# %%
df_a["Date"].value_counts()
# Out:
# 2020-05-09    213
# 2020-05-03    213
# 2020-04-29    213
# 2020-04-21    213
# 2020-05-14    213
# 2020-04-24    213
# 2020-04-28    213
# 2020-05-05    213
# 2020-05-04    213
# 2020-04-19    213
# 2020-05-13    213
# 2020-04-23    213
# 2020-05-12    213
# 2020-04-30    213
# 2020-05-18    213
# 2020-05-11    213
# 2020-05-08    213
# 2020-04-18    213
# 2020-04-26    213
# 2020-04-25    213
# 2020-04-20    213
# 2020-05-16    213
# 2020-05-10    213
# 2020-05-01    213
# 2020-05-15    213
# 2020-05-02    213
# 2020-05-07    213
# 2020-05-17    213
# 2020-04-27    213
# 2020-04-22    213
# 2020-05-06    213
# Name: Date, dtype: int64

# %%
#from dates we can get monthly yearly and daily analysis 
df_dates=pd.DataFrame()
df_dates["Month"]=df_a["Date"].dt.month_name()
df_dates["Day"]=df_a["Date"].dt.day_name()

df_dates["Total Tests"]=df_a["Total Tests"]
df_dates["Total Deaths"]=df_a["Total Deaths"]

# %%
df_dates
# Out:
#       Month       Day  Total Tests  Total Deaths
# 0     April  Saturday    3722145.0       39014.0
# 1     April  Saturday    1831892.0         313.0
# 2     April  Saturday     930230.0       20043.0
# 3     April  Saturday      62985.0        2361.0
# 4     April  Saturday     460437.0       15464.0
# ...     ...       ...          ...           ...
# 6598    May    Monday          NaN           NaN
# 6599    May    Monday          NaN           NaN
# 6600    May    Monday          NaN           NaN
# 6601    May    Monday          NaN           NaN
# 6602    May    Monday          NaN           NaN
#
# [6603 rows x 4 columns]

# %%
df_dates.corr()
# Out:
#               Total Tests  Total Deaths
# Total Tests      1.000000      0.811128
# Total Deaths     0.811128      1.000000

# %%
sns.heatmap(df_dates.corr())

# %%
#checking the total deaths b/w months
sns.barplot(x="Month",y="Total Deaths",data=df_dates)

# %%
#checking the total test b/w months
sns.barplot(x="Month",y="Total Tests",data=df_dates)

# %%
#checking the total test b/w days
sns.barplot(x="Day",y="Total Tests",data=df_dates)

# %%
#checking the total test b/w days
sns.barplot(x="Day",y="Total Deaths",data=df_dates)

# %%
df=df_a.copy()
df.head()
# Out:
#         Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0 2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1 2020-04-18  Russia   145927292    1831892.0      36793.0         313.0
# 2 2020-04-18   Spain    46752703     930230.0     194416.0       20043.0
# 3 2020-04-18  Brazil   212380932      62985.0      36722.0        2361.0
# 4 2020-04-18      UK    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases
# 0          68269.0              13551.0      631509.0
# 1           3057.0                  8.0       33423.0
# 2          74797.0               7371.0       99576.0
# 3          14026.0               6634.0       20335.0
# 4              NaN               1559.0       98409.0

# %%
df.drop("Date",axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                   0
# Population                0
# Total Tests            1098
# Total Cases              49
# Total Deaths           1236
# Total Recovered         285
# Serious or Critical    2486
# Active Cases             59
# dtype: int64

# %%
df.dtypes
# Out:
# Country                 object
# Population               int64
# Total Tests            float64
# Total Cases            float64
# Total Deaths           float64
# Total Recovered        float64
# Serious or Critical    float64
# Active Cases           float64
# dtype: object

# %%
sns.heatmap(df.isnull())

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="mean")
list1=['Total Tests' ,'Total Cases','Total Deaths' ,'Total Recovered' ,'Serious or Critical' ,'Active Cases']
for i in list1:
     df[i]=imp.fit_transform(df[i].values.reshape(-1,1))

# %%
sns.heatmap(df.isnull())

# %%
df["Country"].value_counts().head(50)
# Out:
# French Guiana             31
# Syria                     31
# Bahrain                   31
# Macao                     31
# Eswatini                  31
# Tanzania                  31
# Congo                     31
# Argentina                 31
# Fiji                      31
# Romania                   31
# Ukraine                   31
# Qatar                     31
# Anguilla                  31
# Malta                     31
# Belgium                   31
# Saint Lucia               31
# Myanmar                   31
# China                     31
# Papua New Guinea          31
# Aruba                     31
# Burkina Faso              31
# Libya                     31
# Sao Tome and Principe     31
# Botswana                  31
# Iran                      31
# South Sudan               31
# Falkland Islands          31
# Malaysia                  31
# Czechia                   31
# Iraq                      31
# Rwanda                    31
# Togo                      31
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Country"] = le.fit_transform(df["Country"])

# %%
df.dtypes
# Out:
# Country                  int32
# Population               int64
# Total Tests            float64
# Total Cases            float64
# Total Deaths           float64
# Total Recovered        float64
# Serious or Critical    float64
# Active Cases           float64
# dtype: object

# %%
df_corr=df.corr()
df_corr
# Out:
#                       Country  Population  Total Tests  Total Cases  \
# Country              1.000000   -0.028674     0.143290     0.117565
# Population          -0.028674    1.000000     0.223735     0.225844
# Total Tests          0.143290    0.223735     1.000000     0.896328
# Total Cases          0.117565    0.225844     0.896328     1.000000
# Total Deaths         0.116034    0.176773     0.803680     0.930952
# Total Recovered      0.064000    0.309361     0.795205     0.821121
# Serious or Critical  0.080346    0.170461     0.728773     0.881620
# Active Cases         0.125181    0.179359     0.853809     0.975361
#
#                      Total Deaths  Total Recovered  Serious or Critical  \
# Country                  0.116034         0.064000             0.080346
# Population               0.176773         0.309361             0.170461
# Total Tests              0.803680         0.795205             0.728773
# ...

# %%
#plotting heatmap
plt.figure(figsize=(16,10))
sns.heatmap(df_corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_corr,annot=True,fmt=".0%",cmap="Accent")
plt.show()

# %%
plt.figure(figsize=(10,8))
comparison=df.drop("Total Deaths",axis=1).corrwith(df["Total Deaths"])
comparison.plot(kind="bar",grid=True)
plt.xticks(rotation=20)
plt.title("correlation with target Death Variable")
# Out:
# Text(0.5, 1.0, 'correlation with target Death Variable')

# %%
df.nunique()
# Out:
# Country                 213
# Population              213
# Total Tests            3174
# Total Cases            3258
# Total Deaths           1186
# Total Recovered        2269
# Serious or Critical     530
# Active Cases           2681
# dtype: int64

# %%
sns.factorplot(x="Country",y="Total Deaths",data=df,kind="bar",size=5,palette="muted",aspect=10)
print("\n ",df.groupby("Country")["Total Deaths"].value_counts())
# Out:
#   Country  Total Deaths
# 0        36.0             2
#          30.0             1
#          33.0             1
#          40.0             1
#          42.0             1
#                          ..
# 211      7.0             10
#          4.0              3
#          2.0              1
# 212      4.0             27
#          3.0              4
# Name: Total Deaths, Length: 2788, dtype: int64

# %%
sns.scatterplot(x="Total Tests",y="Total Deaths",data=df)

# %%
sns.scatterplot(x="Total Tests",y="Total Recovered",data=df)

# %%
sns.scatterplot(x="Total Recovered",y="Total Cases",data=df)

# %%
sns.scatterplot(x="Serious or Critical",y="Total Deaths",data=df)

# %%
sns.pairplot(df)

# %%
df.skew()
# Out:
# Country                 0.000000
# Population              8.743503
# Total Tests             9.340104
# Total Cases            12.079982
# Total Deaths            8.951957
# Total Recovered         7.220713
# Serious or Critical     9.199670
# Active Cases           13.301517
# dtype: float64

# %%
#removing ouliers
from scipy.stats import zscore
z_scr=abs(zscore(df))
threshold=3
print(np.where(z_scr>3))
df_z=df[(z_scr<3).all(axis=1)]
# Out:
# (array([   0,    0,    0,    0,    0,    2,    2,    2,    3,    5,    6,
#           7,   10,   12,   12,  213,  213,  213,  213,  213,  215,  215,
#         215,  216,  218,  219,  219,  220,  223,  225,  225,  426,  426,
#         426,  426,  426,  428,  428,  428,  429,  431,  432,  432,  433,
#         436,  438,  438,  639,  639,  639,  639,  639,  639,  641,  641,
#         641,  642,  644,  645,  645,  646,  649,  651,  651,  852,  852,
#         852,  852,  852,  852,  854,  854,  854,  855,  857,  858,  858,
#         859,  862,  864,  864, 1065, 1065, 1065, 1065, 1065, 1065, 1066,
#        1067, 1067, 1067, 1068, 1070, 1071, 1071, 1072, 1075, 1077, 1077,
#        1278, 1278, 1278, 1278, 1278, 1278, 1279, 1280, 1280, 1280, 1281,
#        1282, 1283, 1284, 1284, 1285, 1288, 1290, 1290, 1491, 1491, 1491,
#        1491, 1491, 1491, 1492, 1493, 1493, 1493, 1494, 1495, 1496, 1497,
#        1497, 1498, 1501, 1503, 1503, 1704, 1704, 1704, 1704, 1704, 1704,
# ...

# %%
df_z.skew()
# Out:
# Country               -0.011884
# Population             3.880217
# Total Tests            3.860036
# Total Cases            5.183936
# Total Deaths           6.225914
# Total Recovered        6.921157
# Serious or Critical    4.274869
# Active Cases           6.120409
# dtype: float64

# %%
#added 1 to all the dataset so that it wont give zero when log transformqation is used
df_z=df_z+1

# %%
#further treating the skewness

for col in df_z.columns:
    if df_z[col].skew()>0.55:
        df_z[col]=np.log1p(df_z[col])

# %%
df_z.skew()
# Out:
# Country               -0.011884
# Population            -0.794027
# Total Tests           -0.644715
# Total Cases            0.016152
# Total Deaths           0.216842
# Total Recovered        0.112478
# Serious or Critical   -0.312329
# Active Cases           0.022325
# dtype: float64

# %%
#it will show the outliers 
df_z.plot(kind="box",subplots=True,layout=(4,5),figsize=(16,10))
# Out:
# Country                    AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Population              AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Tests              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# Total Cases             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# Total Deaths            AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Recovered           AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Serious or Critical    AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Active Cases            AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# dtype: object

# %%
x=df_z.drop(["Total Deaths"],axis=1)
y=df_z["Total Deaths"]

# %%
df_z=pd.DataFrame(df_z)

# %%
# Out:
#       Country  Population  Total Tests  Total Cases  Total Deaths  \
# 1         159   18.798619    14.420861    10.513117      5.752573
# 4         201   18.032725    13.039936    11.645873      9.646399
# 8         198   18.249063    13.302908    11.318503      7.545390
# 9          94   18.244691    12.707269    11.300598      8.523772
# 11        153   17.309466    11.819653     9.576510      5.857933
# ...       ...         ...          ...          ...           ...
# 6598      183    9.197863    12.286395     2.079442      7.257180
# 6599      210   13.297096    12.286395     2.079442      7.257180
# 6600        6    9.615072    12.286395     1.609438      7.257180
# 6601      111   14.576427    12.286395     1.098612      7.257180
# 6602      166    8.665441    12.286395     1.098612      7.257180
#
#       Total Recovered  Serious or Critical  Active Cases
# 1            8.025843             2.302585     10.417059
# 4            8.675465             7.353082     11.496908
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=89,test_size=.20)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),Lasso(),Ridge()]
max_r2_score= 0
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train, test_size=0.2, random_state=89)
for md in model:
    md.fit(x_train,y_train)
    y_pre=md.predict(x_test)
    r2_scr=r2_score(y_test,y_pre)
    print(r2_scr)
    if r2_scr>max_r2_score:
        max_r2_score=r2_scr
        best_model=md
print()
print()
print()
print("max score ",max_r2_score,"best model is ",best_model)
# Out:
# 0.18361220057794914
# 0.8542160519495101
# 0.8800283300154138
# -0.00012605389467568173
# 0.1836107455514836
#
#
#
# max score  0.8800283300154138 best model is  KNeighborsRegressor()

# %%
#best parameters for knn
parameters={"n_neighbors":range(1,30)}
KNN=KNeighborsRegressor()

gcv=GridSearchCV(KNN,parameters)
gcv.fit(x,y)
print(gcv.best_params_)
# Out:
# {'n_neighbors': 2}

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(n_neighbors=2),Lasso(),Ridge()]
max_r2_score= 0
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train, test_size=0.2, random_state=89)
for md in model:
    md.fit(x_train,y_train)
    y_pre=md.predict(x_test)
    r2_scr=r2_score(y_test,y_pre)
    print(r2_scr)
    if r2_scr>max_r2_score:
        max_r2_score=r2_scr
        best_model=md
print()
print()
print()
print("max score ",max_r2_score,"best model is ",best_model)
# Out:
# 0.1867462370556151
# 0.7981946265160736
# 0.880928884477827
# -0.001779804467402668
# 0.1867783204145208
#
#
#
# max score  0.880928884477827 best model is  KNeighborsRegressor(n_neighbors=2)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(KNeighborsRegressor(n_neighbors=2), x,y, cv=10, scoring='r2').mean()
# Out:
# 0.8604269708870774

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %%
model_boost=[RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor(),BaggingRegressor(),ExtraTreesRegressor()]

for mod in model_boost:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=89,test_size=.20)
    print("*************",mod,"***************")
    mod.fit(x_train,y_train)
    mod.score(x_train,y_train)
    y_pred=mod.predict(x_test)
    print("r2 score of ",mod,"is as follow" )
    print("\n",r2_score(y_test,y_pred))
    print("mean absolute error",mean_absolute_error(y_test,y_pred))
    print("mean squared error",mean_squared_error(y_test,y_pred))
    print("\n\n")
    print("******************************************")
    print("\n\n")
# Out:
# ************* RandomForestRegressor() ***************
# r2 score of  RandomForestRegressor() is as follow
#
#  0.9152793351918557
# mean absolute error 0.1667948053011128
# mean squared error 0.42526390570306155
#
#
#
# ******************************************
#
#
#
# ************* AdaBoostRegressor() ***************
# r2 score of  AdaBoostRegressor() is as follow
#
#  0.32160832222692937
# mean absolute error 1.516984756432126
# mean squared error 3.4052553192251995
#
#
#
# ******************************************
#
#
#
# ************* GradientBoostingRegressor() ***************
# r2 score of  GradientBoostingRegressor() is as follow
#
#  0.7478263831411287
# mean absolute error 0.8109138113235412
# mean squared error 1.2658108557519465
#
#
#
# ******************************************
#
#
#
# ************* BaggingRegressor() ***************
# r2 score of  BaggingRegressor() is as follow
#
#  0.906673575787994
# mean absolute error 0.17473082891281505
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(BaggingRegressor(), x,y, cv=10, scoring='r2').mean()
# Out:
# 0.8637845816749262

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(ExtraTreesRegressor(), x,y, cv=10, scoring='r2').mean()
# Out:
# 0.8576057031987492

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(RandomForestRegressor(), x,y, cv=10, scoring='r2').mean()
# Out:
# 0.8720699833208713

# %%
#Random forest gives the best score of 87 percent
